# %% [markdown]
# # TASK A

# %%
BEGIN
    
    SET subtotal = 0
    SET tax_rate = 0.08  (8% tax)
    SET more_items = TRUE

    
    WHILE more_items IS TRUE
        INPUT item_price
        subtotal = subtotal + item_price
        
        INPUT "Is there another item? (Yes/No)"
        IF response IS "No" THEN
            SET more_items = FALSE
        END IF
    END WHILE

    
    total_tax = subtotal * tax_rate
    final_bill = subtotal + total_tax

    DISPLAY "Subtotal: ", subtotal
    DISPLAY "Tax: ", total_tax
    DISPLAY "Total Amount Due: ", final_bill

    // Step 4: Handle Payment
    INPUT payment_received
    
    IF payment_received >= final_bill THEN
        change = payment_received - final_bill
        DISPLAY "Transaction Successful!"
        DISPLAY "Your change is: ", change
    ELSE
        DISPLAY "Error: Insufficient funds. Please provide more cash."
    END IF

END

# %% [markdown]
# ![Screenshot%202026-03-15%20172724.png](attachment:Screenshot%202026-03-15%20172724.png)

# %% [markdown]
# # TASK B

# %% [markdown]
# ![Screenshot%202026-03-15%20183738.png](attachment:Screenshot%202026-03-15%20183738.png)

# %% [markdown]
# # TASK C

# %%
BEGIN
    INPUT Name1, Age1
    INPUT Name2, Age2
    
    // The "Three-Cup" Swap
    SET temp = Age1    // Store Age1 safely
    SET Age1 = Age2    // Give Age1 the value of Age2
    SET Age2 = temp    // Give Age2 the original value of Age1
    
    DISPLAY Name1, "is now", Age1
    DISPLAY Name2, "is now", Age2
END

# %% [markdown]
# ![Screenshot%202026-03-15%20184009.png](attachment:Screenshot%202026-03-15%20184009.png)
