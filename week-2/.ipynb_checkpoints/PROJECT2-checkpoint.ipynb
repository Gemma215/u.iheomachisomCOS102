# %%
import numpy as np

def get_roots():
    print("-- Polynomial Root Finder --")
    print("Select the degree of the equation:")
    print("1. Quadratic (Ax^2 + Bx + C = 0)")
    print("2. Cubic (Ax^3 + Bx^2 + Cx + D = 0)")
    print("3. Quartic (Ax^4 + Bx^3 + Cx^2 + Dx + E = 0)")
    
    choice = input("\nEnter choice (1, 2, or 3): ")

    try:
        if choice == '1':
            print("\nEnter coefficients for Ax^2 + Bx + C = 0")
            a = float(input("Enter A: "))
            b = float(input("Enter B: "))
            c = float(input("Enter C: "))
            coeffs = [a, b, c]
            
        elif choice == '2':
            print("\nEnter coefficients for Ax^3 + Bx^2 + Cx + D = 0")
            a = float(input("Enter A: "))
            b = float(input("Enter B: "))
            c = float(input("Enter C: "))
            d = float(input("Enter D: "))
            coeffs = [a, b, c, d]
            
        elif choice == '3':
            print("\nEnter coefficients for Ax^4 + Bx^3 + Cx^2 + Dx + E = 0")
            a = float(input("Enter A: "))
            b = float(input("Enter B: "))
            c = float(input("Enter C: "))
            d = float(input("Enter D: "))
            e = float(input("Enter E: "))
            coeffs = [a, b, c, d, e]
            
        else:
            print("Invalid selection. Please run the program again.")
            return

        # Calculate roots
        roots = np.roots(coeffs)
        
        print("\n--- Results ---")
        for i, root in enumerate(roots, 1):
            # Clean up the output for complex numbers
            formatted_root = np.round(root, 4)
            print(f"Root {i}: {formatted_root}")

    except ValueError:
        print("Error: Please enter valid numerical coefficients.")

if __name__ == "__main__":
    get_roots()
# Out:
# -- Polynomial Root Finder --
# Select the degree of the equation:
# 1. Quadratic (Ax^2 + Bx + C = 0)
# 2. Cubic (Ax^3 + Bx^2 + Cx + D = 0)
# 3. Quartic (Ax^4 + Bx^3 + Cx^2 + Dx + E = 0)
#
# Enter choice (1, 2, or 3): 2
#
# Enter coefficients for Ax^3 + Bx^2 + Cx + D = 0
# Enter A: 5
# Enter B: 6
# Enter C: 7
# Enter D: 8
#
# --- Results ---
# Root 1: (-1.1711+0j)
# Root 2: (-0.0144+1.1688j)
# Root 3: (-0.0144-1.1688j)
